# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim

# %%
np.random.seed(42)

# %%
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# %%
plt.scatter(X, y)
plt.xlabel('X')
plt.ylabel('y')
plt.title('Synthetic Data')
plt.show()

# %%
def stochastic_gradient_descent(X, y, learning_rate=0.1, n_epochs=50):
    m, n = X.shape
    X_b = np.c_[np.ones((m, 1)), X]
    theta = np.random.randn(n + 1, 1)
   
    for epoch in range(n_epochs):
        for i in range(m):
            random_index = np.random.randint(m)
            xi = X_b[random_index:random_index + 1]
            yi = y[random_index:random_index + 1]
            gradients = 2 * xi.T.dot(xi.dot(theta) - yi)
            theta -= learning_rate * gradients
    return theta

theta_sgd = stochastic_gradient_descent(X, y)
print("Parameters learned (theta):", theta_sgd)

plt.scatter(X, y, label="Data")
plt.plot(X, theta_sgd[0] + theta_sgd[1] * X, color="red", label="SGD Line")
plt.legend()
plt.xlabel("X")
plt.ylabel("y")
plt.title("SGD Linear Regression Fit")
plt.show()
# Out:
# Parameters learned (theta): [[4.33483995]
#  [2.43658052]]

# %%
X = torch.rand(100, 1) * 10
y = 3 * X + 5 + torch.randn(100, 1) * 2

# %%
model = nn.Linear(1, 1)
model
# Out:
# Linear(in_features=1, out_features=1, bias=True)

# %%
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %%
for epoch in range(100):
    optimizer.zero_grad()
    outputs = model(X)
    loss = criterion(outputs, y) 
    loss.backward()
    optimizer.step()
    print(f"Epoch {epoch + 1}, Loss: {loss.item()}")
    print(f"learned parameters: model.state dict()")
# Out:
# Epoch 1, Loss: 775.5589599609375
# learned parameters: model.state dict()
# Epoch 2, Loss: 32.67166519165039
# learned parameters: model.state dict()
# Epoch 3, Loss: 8.433662414550781
# learned parameters: model.state dict()
# Epoch 4, Loss: 7.608997344970703
# learned parameters: model.state dict()
# Epoch 5, Loss: 7.547447681427002
# learned parameters: model.state dict()
# Epoch 6, Loss: 7.5110859870910645
# learned parameters: model.state dict()
# Epoch 7, Loss: 7.475870132446289
# learned parameters: model.state dict()
# Epoch 8, Loss: 7.44101095199585
# learned parameters: model.state dict()
# Epoch 9, Loss: 7.40648078918457
# learned parameters: model.state dict()
# Epoch 10, Loss: 7.3722758293151855
# learned parameters: model.state dict()
# Epoch 11, Loss: 7.338393688201904
# learned parameters: model.state dict()
# Epoch 12, Loss: 7.304831504821777
# learned parameters: model.state dict()
# Epoch 13, Loss: 7.27158260345459
# learned parameters: model.state dict()
# ...
