# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import OrdinalEncoder
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import svm
from sklearn import tree
from sklearn.ensemble import RandomForestRegressor
from sklearn import linear_model
from sklearn.tree import plot_tree
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import GridSearchCV

# %%
data = pd.read_csv('Employee.csv')

# %%
data
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
data = data.drop_duplicates().reset_index(drop=True)

# %%
data
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 2759    Masters         2017       Pune            2   31  Female          No
# 2760  Bachelors         2016       Pune            3   30    Male          No
# 2761    Masters         2013       Pune            2   37    Male          No
# 2762    Masters         2018  New Delhi            3   27    Male          No
# 2763  Bachelors         2012  Bangalore            3   30    Male         Yes
#
# ...

# %%
#How many people left by education
data.groupby('Education')['LeaveOrNot'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Education'>

# %%
data['Education'].value_counts()
# Out:
# Education
# Bachelors    1971
# Masters       637
# PHD           156
# Name: count, dtype: int64

# %%
#City vs leave or not
data.groupby('City')['LeaveOrNot'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='City'>

# %%
#City vs leave or not
data.groupby('City')['LeaveOrNot'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='City,LeaveOrNot'>

# %%
data.groupby('EverBenched')['LeaveOrNot'].value_counts()
# Out:
# EverBenched  LeaveOrNot
# No           0             1474
#              1              929
# Yes          0              202
#              1              159
# Name: count, dtype: int64

# %%
data.groupby('PaymentTier')['LeaveOrNot'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='PaymentTier,LeaveOrNot'>

# %%
data.head()
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# 2                          2           0
# 3                          5           1
# 4                          2           1

# %%
#Average age of people the stayed and left
data.groupby('LeaveOrNot')['Age'].mean().sort_values(ascending=False)
# Out:
# LeaveOrNot
# 0    31.426014
# 1    30.224265
# Name: Age, dtype: float64

# %%
data.groupby('LeaveOrNot')['Age'].median().sort_values(ascending=False)
# Out:
# LeaveOrNot
# 0    30.0
# 1    29.0
# Name: Age, dtype: float64

# %%
data.groupby('LeaveOrNot')['ExperienceInCurrentDomain'].mean()
# Out:
# LeaveOrNot
# 0    2.671838
# 1    2.602022
# Name: ExperienceInCurrentDomain, dtype: float64

# %%
data.groupby('LeaveOrNot')['JoiningYear'].value_counts()
# Out:
# LeaveOrNot  JoiningYear
# 0           2017           461
#             2015           272
#             2014           266
#             2012           225
#             2013           225
#             2016           222
#             2018             5
# 1           2018           234
#             2017           201
#             2015           192
#             2013           171
#             2014           119
#             2016            88
#             2012            83
# Name: count, dtype: int64

# %%
data.head()
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# 2                          2           0
# 3                          5           1
# 4                          2           1

# %%
# Encode data
oe = OrdinalEncoder()

oe.fit(data[['Education','City','Gender','EverBenched']])
# Out:
# OrdinalEncoder()

# %%
data[['Education','City','Gender','EverBenched']] = oe.transform(data[['Education','City','Gender','EverBenched']])

# %%
data
# Out:
#       Education  JoiningYear  City  PaymentTier  Age  Gender  EverBenched  \
# 0           0.0         2017   0.0            3   34     1.0          0.0
# 1           0.0         2013   2.0            1   28     0.0          0.0
# 2           0.0         2014   1.0            3   38     0.0          0.0
# 3           1.0         2016   0.0            3   27     1.0          0.0
# 4           1.0         2017   2.0            3   24     1.0          1.0
# ...         ...          ...   ...          ...  ...     ...          ...
# 2759        1.0         2017   2.0            2   31     0.0          0.0
# 2760        0.0         2016   2.0            3   30     1.0          0.0
# 2761        1.0         2013   2.0            2   37     1.0          0.0
# 2762        1.0         2018   1.0            3   27     1.0          0.0
# 2763        0.0         2012   0.0            3   30     1.0          1.0
#
#       ExperienceInCurrentDomain  LeaveOrNot
# ...

# %%
X = data.iloc[:,:-1]
Y = data[['LeaveOrNot']]

# %%
#Scaling Only continious values, this instance has only one continious column so none needed
X_scaller = StandardScaler()
Y_scaller = StandardScaler()

# %%
#Split into train and test
#Put a smaller test size because of the smaller data(2764) 0.15
X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size = 0.15, random_state = 23)

# %%
X_train.shape
# Out:
# (2349, 8)

# %%
Y_train.shape
# Out:
# (2349, 1)

# %%
#Fit the models
