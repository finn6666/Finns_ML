# %%
import pandas as pd
from pycaret.regression import *
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("demographic_data.csv")

# %%
data.head()
# Out:
#            County    State  State FIPS Code  County FIPS Code  FIPS  \
# 0  Autauga County  Alabama                1                 1  1001
# 1  Baldwin County  Alabama                1                 3  1003
# 2  Barbour County  Alabama                1                 5  1005
# 3     Bibb County  Alabama                1                 7  1007
# 4   Blount County  Alabama                1                 9  1009
#
#    Total Population  Male Population  Female Population  Total Race Responses  \
# 0             59285            28669              30616                 59285
# 1            239945           117316             122629                239945
# 2             24757            12906              11851                 24757
# 3             22152            11824              10328                 22152
# 4             59292            29934              29358                 59292
#
#    White Alone  Black or African American Alone  Hispanic or Latino
# ...

# %%
data.shape
# Out:
# (3222, 12)

# %%
data_1 = data.sample(frac=0.9, random_state=786).reset_index(drop=True)
data_unseen = data.drop(data_1.index).reset_index(drop=True)

print('Data for Modeling: ' + str(data_1.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (2900, 12)
# Unseen Data For Predictions: (322, 12)

# %%
data_1.isnull().sum()
# Out:
# County                             0
# State                              0
# State FIPS Code                    0
# County FIPS Code                   0
# FIPS                               0
# Total Population                   0
# Male Population                    0
# Female Population                  0
# Total Race Responses               0
# White Alone                        0
# Black or African American Alone    0
# Hispanic or Latino                 0
# dtype: int64

# %%
data_1.duplicated().sum()
# Out:
# 0

# %%
data.head()
# Out:
#            County    State  State FIPS Code  County FIPS Code  FIPS  \
# 0  Autauga County  Alabama                1                 1  1001
# 1  Baldwin County  Alabama                1                 3  1003
# 2  Barbour County  Alabama                1                 5  1005
# 3     Bibb County  Alabama                1                 7  1007
# 4   Blount County  Alabama                1                 9  1009
#
#    Total Population  Male Population  Female Population  Total Race Responses  \
# 0             59285            28669              30616                 59285
# 1            239945           117316             122629                239945
# 2             24757            12906              11851                 24757
# 3             22152            11824              10328                 22152
# 4             59292            29934              29358                 59292
#
#    White Alone  Black or African American Alone  Hispanic or Latino
# ...

# %%
sns.histplot(data=data_1,x='Total Population')
plt.show()

# %%
med = data_1['Total Population'].median()

# %%
data_1['Total Population'].sort_values().head()
# Out:
# 2093     43
# 1041     52
# 370      54
# 2830    385
# 403     463
# Name: Total Population, dtype: int64

# %%
exp_reg101 = setup(data=data_1, target = 'Hispanic or Latino', session_id=123)
# Out:
# <style type="text/css">
# #T_e0510_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e0510">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e0510_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e0510_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0510_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e0510_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e0510_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_e0510_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e0510_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e0510_row1_col1" class="data row1 col1" >Hispanic or Latino</td>
#     </tr>
#     <tr>
#       <th id="T_e0510_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_6b735 th {
#   text-align: left;
# }
# ...
